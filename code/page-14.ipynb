# %% [markdown]
# #### محمود امین طوسی - درس متن‌کاوی
#  مثال صفحه ۱۴ کتاب
#
#  Natural Language Processing with Python

# %%
for line in open("../data/Anne_of_Green_Gables.txt"):
    for word in line.split():
        if word.endswith('ert'):
            print(word)
# Out:
# Cuthbert
# Cuthbert
# Concert
# Concert
# Concert
# Cuthbert
# Cuthbert
# Cuthbert
# Cuthbert
# Cuthbert
# Cuthbert
# Cuthbert
# Cuthbert
# Robert
# Cuthbert
# Cuthbert
# Cuthbert
# Cuthbert
# Cuthbert
# Robert
# Robert
# Cuthbert
# Cuthbert
# Cuthbert
# Gilbert
# “Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# “Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Cuthbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Cuthbert
# Gilbert
# Concert
# concert
# concert
# concert
# Gilbert
# concert
# concert
# Gilbert
# Gilbert
# Cuthbert
# Cuthbert
# Cuthbert
# concert
# concert
# Concert
# concert
# concert
# Cuthbert
# Cuthbert
# concert
# “Gilbert
# concert
# concert
# concert
# concert
# alert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# Gilbert
# ...
