# %% [markdown]
# مثال‌های فصل دوم
# محمود امین طوسی

# %%
from random import random

def generate_letter(lm, history, order):
        history = history[-order:]
        dist = lm[history]
        x = random()
        for c,v in dist:
            x = x - v
            if x <= 0: return c

# %%
def generate_text(lm, order, nletters=1000):
    history = "~" * order
    out = []
    for i in range(nletters):
        c = generate_letter(lm, history, order)
        history = history[-order:] + c
        out.append(c)
    return "".join(out)

# %%
from collections import *

def train_char_lm(fname, order=4):
    data = open(fname).read()
    lm = defaultdict(Counter)
    pad = "~" * order
    data = pad + data
    for i in range(len(data)-order):
        history, char = data[i:i+order], data[i+order]
        lm[history][char]+=1
    def normalize(counter):
        s = float(sum(counter.values()))
        return [(c,cnt/s) for c,cnt in counter.items()]
    outlm = {hist:normalize(chars) for hist, chars in lm.items()}
    return outlm

# %%
fname = "../data/Anne_of_Green_Gables.txt"
order = 4
data = open(fname).read()
lm = defaultdict(Counter)

# %%
pad = "~" * order
data = pad + data
for i in range(len(data)-order):
    history, char = data[i:i+order], data[i+order]
    lm[history][char]+=1
    
# lm.items()

# %%
def normalize(counter):
    s = float(sum(counter.values()))
    return [(c,cnt/s) for c,cnt in counter.items()]
outlm = {hist:normalize(chars) for hist, chars in lm.items()}

# %%
outlm
# Out:
# {'~~~~': [('T', 0.2), ('~', 0.8)],
#  '~~~T': [('i', 1.0)],
#  '~~Ti': [('t', 1.0)],
#  '~Tit': [('l', 1.0)],
#  'Titl': [('e', 1.0)],
#  'itle': [(':', 0.3333333333333333),
#   ('s', 0.3333333333333333),
#   ('d', 0.3333333333333333)],
#  'tle:': [(' ', 1.0)],
#  'le: ': [('A', 1.0)],
#  'e: A': [('n', 1.0)],
#  ': An': [('n', 1.0)],
#  ' Ann': [('e', 0.9989561586638831), (' ', 0.0010438413361169101)],
#  'Anne': [(' ', 0.5538079470198676),
#   ('’', 0.0869205298013245),
#   (',', 0.17798013245033112),
#   ('\n', 0.03145695364238411),
#   ('.', 0.11341059602649006),
#   ('?', 0.018211920529801324),
#   ('-', 0.009933774834437087),
#   ('!', 0.0033112582781456954),
#   (';', 0.0016556291390728477),
#   ('s', 0.0008278145695364238),
#   ('”', 0.0016556291390728477),
#   (']', 0.0008278145695364238)],
#  'nne ': [('o', 0.02391629297458894),
#   ('S', 0.06726457399103139),
#   ('t', 0.061285500747384154),
#   ('i', 0.03288490284005979),
#   ('C', 0.0029895366218236174),
#   ('s', 0.10762331838565023),
#   ('c', 0.061285500747384154),
#   ('n', 0.016442451420029897),
#   ('l', 0.04783258594917788),
#   ('h', 0.09267563527653214),
#   ('a', 0.07473841554559044),
#   ('d', 0.04484304932735426),
#   ('b', 0.02242152466367713),
#   ('r', 0.04633781763826607),
#   ('w', 0.11659192825112108),
#   ('f', 0.059790732436472344),
#   ('g', 0.028400597907324365),
#   ('m', 0.028400597907324365),
#   ('u', 0.0014947683109118087),
#   ('k', 0.007473841554559043),
#   ('p', 0.02391629297458894),
#   ('“', 0.0014947683109118087),
#   ('e', 0.016442451420029897),
#   ('M', 0.0014947683109118087),
#   ('_', 0.0014947683109118087),
#   ('q', 0.004484304932735426),
#   ('(', 0.0014947683109118087),
#   ('j', 0.0029895366218236174),
#   ('I', 0.0014947683109118087)],
#  'ne o': [('f', 0.6972477064220184),
#   ('r', 0.07339449541284404),
#   ('u', 0.10091743119266056),
#   ('v', 0.045871559633027525),
#   ('p', 0.03669724770642202),
#   ('t', 0.009174311926605505),
#   ('n', 0.027522935779816515),
#   ('l', 0.009174311926605505)],
#  'e of': [(' ', 0.8537859007832899),
#   ('-', 0.005221932114882507),
#   ('f', 0.06527415143603134),
#   ('\n', 0.06266318537859007),
#   ('t', 0.010443864229765013),
#   ('.', 0.0026109660574412533)],
#  ' of ': [('G', 0.006723716381418093),
#   ('C', 0.003056234718826406),
#   ('S', 0.01650366748166259),
#   ('A', 0.019559902200488997),
#   ('H', 0.0024449877750611247),
#   ('t', 0.25183374083129584),
#   ('p', 0.029339853300733496),
#   ('i', 0.06601466992665037),
#   ('n', 0.009168704156479218),
#   ('o', 0.011002444987775062),
#   ('M', 0.012224938875305624),
#   ('c', 0.03850855745721271),
#   ('y', 0.030562347188264057),
#   ('m', 0.039119804400977995),
#   ('a', 0.09352078239608802),
#   ('h', 0.08801955990220049),
#   ('d', 0.029951100244498777),
#   ('v', 0.004889975550122249),
#   ('s', 0.05806845965770171),
#   ('e', 0.015281173594132029),
#   ('b', 0.028728606356968216),
#   ('w', 0.02628361858190709),
#   ('l', 0.021393643031784843),
#   ('r', 0.021393643031784843),
#   ('D', 0.003056234718826406),
#   ('g', 0.021393643031784843),
#   ('f', 0.02078239608801956),
#   ('u', 0.005501222493887531),
#   ('‘', 0.0006112469437652812),
#   ('P', 0.0012224938875305623),
#   ('j', 0.003667481662591687),
#   ('B', 0.0012224938875305623),
#   ('q', 0.0012224938875305623),
#   ('k', 0.003667481662591687),
#   ('R', 0.0012224938875305623),
#   ('“', 0.0024449877750611247),
#   ('J', 0.004278728606356968),
#   ('V', 0.0006112469437652812),
#   ('W', 0.0006112469437652812),
#   ('T', 0.0006112469437652812),
#   ('L', 0.0012224938875305623),
#   ('O', 0.0006112469437652812),
#   ('N', 0.0012224938875305623),
#   ('Q', 0.0012224938875305623)],
#  'of G': [('r', 0.8181818181818182),
#   ('i', 0.09090909090909091),
#   ('o', 0.09090909090909091)],
#  'f Gr': [('e', 1.0)],
#  ' Gre': [('e', 0.9655172413793104),
#   ('s', 0.011494252873563218),
#   ('a', 0.022988505747126436)],
#  'Gree': [('n', 0.9787234042553191), ('k', 0.02127659574468085)],
#  'reen': [(' ', 0.7928571428571428),
#   ('\n', 0.07857142857142857),
#   ('e', 0.007142857142857143),
#   (',', 0.05714285714285714),
#   ('s', 0.02857142857142857),
#   ('-', 0.007142857142857143),
#   ('?', 0.007142857142857143),
#   ('!', 0.007142857142857143),
#   ('.', 0.007142857142857143),
#   ('”', 0.007142857142857143)],
#  'een ': [('G', 0.20935960591133004),
#   ('o', 0.03694581280788178),
#   ('g', 0.022167487684729065),
#   ('s', 0.08620689655172414),
#   ('k', 0.009852216748768473),
#   ('a', 0.1330049261083744),
#   ('i', 0.04433497536945813),
#   ('c', 0.027093596059113302),
#   ('M', 0.009852216748768473),
#   ('e', 0.019704433497536946),
#   ('m', 0.03201970443349754),
#   ('d', 0.03201970443349754),
#   ('t', 0.11576354679802955),
#   ('q', 0.0049261083743842365),
#   ('w', 0.034482758620689655),
#   ('f', 0.022167487684729065),
#   ('b', 0.024630541871921183),
#   ('l', 0.017241379310344827),
#   ('h', 0.03694581280788178),
#   ('r', 0.014778325123152709),
#   ('u', 0.007389162561576354),
#   ('p', 0.024630541871921183),
#   ('n', 0.012315270935960592),
#   ('A', 0.0049261083743842365),
#   ('D', 0.0024630541871921183),
#   ('v', 0.0024630541871921183),
#   ('y', 0.007389162561576354),
#   ('C', 0.0049261083743842365)],
#  'en G': [('a', 0.9767441860465116), ('i', 0.023255813953488372)],
#  'n Ga': [('b', 1.0)],
#  ' Gab': [('l', 0.9882352941176471), ('r', 0.011764705882352941)],
#  'Gabl': [('e', 1.0)],
#  'able': [('s', 0.2897196261682243),
#   (' ', 0.48598130841121495),
#   ('\n', 0.04984423676012461),
#   ('.', 0.08411214953271028),
#   (',', 0.059190031152647975),
#   ('-', 0.003115264797507788),
#   (';', 0.006230529595015576),
#   ('a', 0.009345794392523364),
#   ('t', 0.003115264797507788),
#   ('_', 0.006230529595015576),
#   ('!', 0.003115264797507788)],
#  'bles': [('\n', 0.02631578947368421),
#   ('.', 0.24561403508771928),
#   (' ', 0.35964912280701755),
#   ('?', 0.03508771929824561),
#   ('s', 0.11403508771929824),
#   (';', 0.017543859649122806),
#   (',', 0.14912280701754385),
#   ('-', 0.02631578947368421),
#   ('o', 0.008771929824561403),
#   ('!', 0.017543859649122806)],
#  'les\n': [('\n', 0.25), (' ', 0.125), ('a', 0.25), ('o', 0.25), ('t', 0.125)],
#  'es\n\n': [('A', 0.25), ('\n', 0.5), (' ', 0.25)],
#  's\n\nA': [('u', 1.0)],
#  '\n\nAu': [('t', 1.0)],
#  '\nAut': [('h', 1.0)],
#  'Auth': [('o', 1.0)],
#  'utho': [('r', 1.0)],
#  'thor': [(':', 0.05555555555555555),
#   ('o', 0.7777777777777778),
#   ('n', 0.1111111111111111),
#   ('i', 0.05555555555555555)],
#  'hor:': [(' ', 1.0)],
#  'or: ': [('L', 1.0)],
#  'r: L': [('u', 1.0)],
#  ': Lu': [('c', 1.0)],
#  ' Luc': [('y', 0.6666666666666666), ('i', 0.3333333333333333)],
#  'Lucy': [(' ', 1.0)],
#  'ucy ': [('M', 0.5), ('a', 0.25), ('t', 0.25)],
#  'cy M': [('a', 0.6666666666666666), ('r', 0.3333333333333333)],
#  'y Ma': [('u', 0.1111111111111111),
#   ('i', 0.1111111111111111),
#   ('t', 0.2222222222222222),
#   ('r', 0.5555555555555556)],
#  ' Mau': [('d', 0.2), ('r', 0.8)],
#  'Maud': [(' ', 1.0)],
#  'aud ': [('M', 1.0)],
#  'ud M': [('o', 1.0)],
#  'd Mo': [('n', 0.3333333333333333),
#   ('t', 0.2222222222222222),
#   ('o', 0.4444444444444444)],
#  ' Mon': [('t', 0.3076923076923077), ('d', 0.6923076923076923)],
#  'Mont': [('g', 0.5), ('m', 0.5)],
#  'ontg': [('o', 1.0)],
#  'ntgo': [('m', 1.0)],
#  'tgom': [('e', 1.0)],
#  'gome': [('r', 1.0)],
#  'omer': [('y', 0.4), ('.', 0.2), ('s', 0.2), (' ', 0.2)],
#  'mery': [('\n', 0.6666666666666666), (' ', 0.3333333333333333)],
#  'ery\n': [('\n', 0.05263157894736842),
#   ('a', 0.07894736842105263),
#   ('t', 0.05263157894736842),
#   ('u', 0.02631578947368421),
#   ('w', 0.05263157894736842),
#   ('s', 0.21052631578947367),
#   ('d', 0.10526315789473684),
#   ('h', 0.02631578947368421),
#   ('c', 0.02631578947368421),
#   ('e', 0.05263157894736842),
#   ('m', 0.10526315789473684),
#   ('g', 0.02631578947368421),
#   ('i', 0.05263157894736842),
#   ('r', 0.05263157894736842),
#   ('p', 0.05263157894736842),
#   ('b', 0.02631578947368421)],
#  'ry\n\n': [('\n', 1.0)],
#  'y\n\n\n': [('R', 0.25), ('\n', 0.25), ('|', 0.5)],
#  '\n\n\nR': [('e', 1.0)],
#  '\n\nRe': [('l', 1.0)],
#  '\nRel': [('e', 1.0)],
#  'Rele': [('a', 1.0)],
#  'elea': [('s', 1.0)],
#  'leas': [('e', 0.423728813559322),
#   ('t', 0.2796610169491525),
#   ('a', 0.211864406779661),
#   ('u', 0.0847457627118644)],
#  'ease': [(' ', 0.5357142857142857),
#   ('?', 0.03571428571428571),
#   (',', 0.17857142857142858),
#   ('\n', 0.03571428571428571),
#   ('d', 0.17857142857142858),
#   ('s', 0.017857142857142856),
#   ('.', 0.017857142857142856)],
#  'ase ': [('D', 0.0196078431372549),
#   ('w', 0.0392156862745098),
#   ('o', 0.0784313725490196),
#   ('t', 0.13725490196078433),
#   ('c', 0.0784313725490196),
#   ('d', 0.09803921568627451),
#   ('e', 0.058823529411764705),
#   ('l', 0.0392156862745098),
#   ('i', 0.0196078431372549),
#   ('a', 0.0784313725490196),
#   ('g', 0.0196078431372549),
#   ('s', 0.058823529411764705),
#   ('f', 0.09803921568627451),
#   ('h', 0.0784313725490196),
#   ('y', 0.0392156862745098),
#   ('I', 0.0392156862745098),
#   ('u', 0.0196078431372549)],
#  'se D': [('a', 0.5), ('i', 0.5)],
#  'e Da': [('t', 0.3333333333333333),
#   ('y', 0.3333333333333333),
#   ('i', 0.3333333333333333)],
#  ' Dat': [('e', 1.0)],
#  'Date': [(':', 1.0)],
#  'ate:': [(' ', 1.0)],
#  'te: ': [('1', 1.0)],
#  'e: 1': [('9', 1.0)],
#  ': 19': [('9', 1.0)],
#  ' 199': [('2', 1.0)],
#  '1992': [(' ', 1.0)],
#  '992 ': [('[', 1.0)],
#  '92 [': [('E', 1.0)],
#  '2 [E': [('B', 1.0)],
#  ' [EB': [('o', 1.0)],
#  '[EBo': [('o', 1.0)],
#  'EBoo': [('k', 1.0)],
#  'Book': [(' ', 1.0)],
#  'ook ': [('#', 0.004149377593360996),
#   ('a', 0.3360995850622407),
#   ('t', 0.11618257261410789),
#   ('c', 0.008298755186721992),
#   ('f', 0.04149377593360996),
#   ('i', 0.058091286307053944),
#   ('l', 0.03319502074688797),
#   ('n', 0.016597510373443983),
#   ('o', 0.07053941908713693),
#   ('b', 0.03319502074688797),
#   ('r', 0.02074688796680498),
#   ('I', 0.008298755186721992),
#   ('h', 0.0912863070539419),
#   ('u', 0.029045643153526972),
#   ('A', 0.012448132780082987),
#   ('s', 0.03319502074688797),
#   ('w', 0.024896265560165973),
#   ('m', 0.004149377593360996),
#   ('D', 0.004149377593360996),
#   ('d', 0.004149377593360996),
#   ('y', 0.008298755186721992),
#   ('M', 0.016597510373443983),
#   ('J', 0.004149377593360996),
#   ('v', 0.008298755186721992),
#   ('j', 0.004149377593360996),
#   ('B', 0.004149377593360996),
#   ('k', 0.004149377593360996)],
#  'ok #': [('4', 1.0)],
#  'k #4': [('5', 1.0)],
#  ' #45': [(']', 1.0)],
#  '#45]': [('\n', 1.0)],
#  '45]\n': [('L', 1.0)],
#  '5]\nL': [('a', 1.0)],
#  ']\nLa': [('s', 1.0)],
#  '\nLas': [('t', 1.0)],
#  'Last': [(' ', 1.0)],
#  'ast ': [('U', 0.005780346820809248),
#   ('M', 0.017341040462427744),
#   ('t', 0.11560693641618497),
#   ('e', 0.04046242774566474),
#   ('n', 0.12716763005780346),
#   ('a', 0.057803468208092484),
#   ('o', 0.03468208092485549),
#   ('w', 0.08092485549132948),
#   ('b', 0.011560693641618497),
#   ('h', 0.03468208092485549),
#   ('I', 0.011560693641618497),
#   ('g', 0.14450867052023122),
#   ('i', 0.046242774566473986),
#   ('y', 0.028901734104046242),
#   ('f', 0.028901734104046242),
#   ('l', 0.005780346820809248),
#   ('s', 0.08092485549132948),
#   ('v', 0.005780346820809248),
#   ('d', 0.03468208092485549),
#   ('S', 0.04046242774566474),
#   ('W', 0.011560693641618497),
#   ('p', 0.011560693641618497),
#   ('m', 0.017341040462427744),
#   ('r', 0.005780346820809248)],
#  'st U': [('p', 1.0)],
#  't Up': [('d', 0.3333333333333333), (' ', 0.6666666666666666)],
#  ' Upd': [('a', 1.0)],
#  'Upda': [('t', 1.0)],
#  'pdat': [('e', 1.0)],
#  'date': [('d', 0.5), ('s', 0.5)],
#  'ated': [(':', 0.012195121951219513),
#   (' ', 0.6585365853658537),
#   ('.', 0.13414634146341464),
#   ('\n', 0.08536585365853659),
#   (',', 0.07317073170731707),
#   ('”', 0.012195121951219513),
#   ('l', 0.012195121951219513),
#   ('_', 0.012195121951219513)],
#  'ted:': [(' ', 1.0)],
#  'ed: ': [('O', 0.5), ('“', 0.5)],
#  'd: O': [('c', 1.0)],
#  ': Oc': [('t', 1.0)],
#  ' Oct': [('o', 1.0)],
#  'Octo': [('b', 1.0)],
#  'ctob': [('e', 1.0)],
#  'tobe': [('r', 1.0)],
#  'ober': [(' ', 0.35714285714285715),
#   ('t', 0.21428571428571427),
#   ('l', 0.14285714285714285),
#   ('e', 0.07142857142857142),
#   ('s', 0.07142857142857142),
#   (',', 0.14285714285714285)],
#  'ber ': [('6', 0.025),
#   ('b', 0.025),
#   ('f', 0.05),
#   ('i', 0.1),
#   ('w', 0.1),
#   ('t', 0.225),
#   ('c', 0.05),
#   ('a', 0.075),
#   ('o', 0.15),
#   ('d', 0.025),
#   ('n', 0.025),
#   ('m', 0.05),
#   ('h', 0.025),
#   ('e', 0.05),
#   ('r', 0.025)],
#  'er 6': [(',', 1.0)],
#  'r 6,': [(' ', 1.0)],
#  ' 6, ': [('2', 1.0)],
#  '6, 2': [('0', 1.0)],
#  ', 20': [('1', 1.0)],
#  ' 201': [('6', 1.0)],
#  '2016': [('\n', 1.0)],
#  '016\n': [('\n', 1.0)],
#  '16\n\n': [('L', 1.0)],
#  '6\n\nL': [('a', 1.0)],
#  '\n\nLa': [('n', 1.0)],
#  '\nLan': [('g', 0.3333333333333333), ('e', 0.6666666666666666)],
#  'Lang': [('u', 1.0)],
#  'angu': [('a', 0.3333333333333333),
#   ('l', 0.1111111111111111),
#   ('i', 0.5555555555555556)],
#  'ngua': [('g', 1.0)],
#  'guag': [('e', 1.0)],
#  'uage': [(':', 0.3333333333333333), (' ', 0.6666666666666666)],
#  'age:': [(' ', 1.0)],
#  'ge: ': [('E', 1.0)],
#  'e: E': [('n', 1.0)],
#  ': En': [('g', 1.0)],
#  ' Eng': [('l', 1.0)],
#  'Engl': [('i', 0.9), ('a', 0.1)],
#  'ngli': [('s', 0.75), ('n', 0.25)],
#  'glis': [('h', 0.6428571428571429), ('t', 0.35714285714285715)],
#  'lish': [('\n', 0.125),
#   (' ', 0.5416666666666666),
#   ('m', 0.041666666666666664),
#   (',', 0.08333333333333333),
#   ('n', 0.08333333333333333),
#   ('e', 0.08333333333333333),
#   ('.', 0.041666666666666664)],
#  'ish\n': [('\n', 0.25), ('J', 0.25), ('h', 0.25), ('e', 0.25)],
#  'sh\n\n': [('\n', 1.0)],
#  'h\n\n\n': [('A', 0.5), ('|', 0.5)],
#  '\n\n\nA': [('N', 0.6666666666666666), ('n', 0.3333333333333333)],
#  '\n\nAN': [('N', 1.0)],
#  '\nANN': [('E', 1.0)],
#  'ANNE': [(' ', 0.8571428571428571), ('’', 0.14285714285714285)],
#  'NNE ': [('O', 0.3333333333333333), ('h', 0.5), ('w', 0.16666666666666666)],
#  'NE O': [('F', 1.0)],
#  'E OF': [(' ', 1.0)],
#  ' OF ': [('G', 1.0)],
#  'OF G': [('R', 1.0)],
#  'F GR': [('E', 1.0)],
#  ' GRE': [('E', 1.0)],
#  'GREE': [('N', 1.0)],
#  'REEN': [(' ', 1.0)],
#  'EEN ': [('G', 1.0)],
#  'EN G': [('A', 1.0)],
#  'N GA': [('B', 1.0)],
#  ' GAB': [('L', 1.0)],
#  'GABL': [('E', 1.0)],
#  'ABLE': [('S', 1.0)],
#  'BLES': [('\n', 1.0)],
#  'LES\n': [('\n', 1.0)],
#  'ES\n\n': [('B', 0.5), ('\n', 0.5)],
#  'S\n\nB': [('y', 1.0)],
#  '\n\nBy': [(' ', 1.0)],
#  '\nBy ': [('L', 1.0)],
#  'By L': [('u', 1.0)],
#  'y Lu': [('c', 1.0)],
#  '\n\n\n\n': [('T', 0.013157894736842105),
#   ('\n', 0.47368421052631576),
#   ('A', 0.013157894736842105),
#   ('C', 0.5)],
#  '\n\n\nT': [('a', 0.5), ('h', 0.5)],
#  '\n\nTa': [('b', 1.0)],
#  '\nTab': [('l', 1.0)],
#  'Tabl': [('e', 1.0)],
#  'ble ': [('o', 0.06477732793522267),
#   ('c', 0.044534412955465584),
#   ('h', 0.03643724696356275),
#   ('a', 0.145748987854251),
#   ('b', 0.032388663967611336),
#   ('s', 0.048582995951417005),
#   ('f', 0.06477732793522267),
#   ('w', 0.10121457489878542),
#   ('t', 0.19433198380566802),
#   ('n', 0.020242914979757085),
#   ('i', 0.044534412955465584),
#   ('p', 0.03643724696356275),
#   ('e', 0.008097165991902834),
#   ('l', 0.020242914979757085),
#   ('m', 0.02834008097165992),
#   ('d', 0.03643724696356275),
#   ('r', 0.032388663967611336),
#   ('I', 0.004048582995951417),
#   ('y', 0.008097165991902834),
#   ('g', 0.008097165991902834),
#   ('M', 0.004048582995951417),
#   ('j', 0.004048582995951417),
#   ('k', 0.004048582995951417),
#   ('J', 0.004048582995951417),
#   ('v', 0.004048582995951417)],
#  'le o': [('f', 0.5972222222222222),
#   ('d', 0.013888888888888888),
#   ('r', 0.1388888888888889),
#   ('n', 0.20833333333333334),
#   ('v', 0.027777777777777776),
#   ('c', 0.013888888888888888)],
#  'of C': [('o', 0.3333333333333333),
#   ('a', 0.3333333333333333),
#   ('h', 0.3333333333333333)],
#  'f Co': [('n', 0.3333333333333333), ('r', 0.6666666666666666)],
#  ' Con': [('t', 0.06666666666666667),
#   ('f', 0.26666666666666666),
#   ('c', 0.4),
#   ('s', 0.26666666666666666)],
#  'Cont': [('e', 1.0)],
#  'onte': [('n', 0.47058823529411764),
#   ('m', 0.23529411764705882),
#   ('d', 0.23529411764705882),
#   ('s', 0.058823529411764705)],
#  'nten': [('t', 0.26666666666666666),
#   ('c', 0.08888888888888889),
#   ('d', 0.4444444444444444),
#   ('a', 0.08888888888888889),
#   ('s', 0.1111111111111111)],
#  'tent': [('s', 0.043478260869565216),
#   ('e', 0.08695652173913043),
#   (' ', 0.2608695652173913),
#   ('l', 0.13043478260869565),
#   ('i', 0.21739130434782608),
#   ('a', 0.08695652173913043),
#   ('.', 0.13043478260869565),
#   (';', 0.043478260869565216)],
#  'ents': [('\n', 0.1276595744680851),
#   (' ', 0.6595744680851063),
#   ('’', 0.02127659574468085),
#   (',', 0.10638297872340426),
#   ('.', 0.0425531914893617),
#   (';', 0.02127659574468085),
#   (':', 0.02127659574468085)],
#  'nts\n': [('\n', 0.14285714285714285),
#   ('i', 0.14285714285714285),
#   ('l', 0.14285714285714285),
#   ('w', 0.14285714285714285),
#   ('d', 0.14285714285714285),
#   ('g', 0.14285714285714285),
#   ('a', 0.14285714285714285)],
#  'ts\n\n': [(' ', 0.5), ('\n', 0.5)],
#  's\n\n ': [(' ', 1.0)],
#  '\n\n  ': [(' ', 0.8181818181818182),
#   ('W', 0.09090909090909091),
#   ('T', 0.09090909090909091)],
#  '\n   ': [(' ', 0.8032786885245902),
#   ('“', 0.03278688524590164),
#   ('W', 0.01639344262295082),
#   ('a', 0.03278688524590164),
#   ('t', 0.04918032786885246),
#   ('n', 0.01639344262295082),
#   ('m', 0.01639344262295082),
#   ('I', 0.03278688524590164)],
#  '    ': [(' ', 0.7220447284345048),
#   ('C', 0.12140575079872204),
#   ('M', 0.025559105431309903),
#   ('A', 0.06070287539936102),
#   ('T', 0.038338658146964855),
#   ('D', 0.003194888178913738),
#   ('V', 0.003194888178913738),
#   ('W', 0.003194888178913738),
#   ('“', 0.01597444089456869),
#   ('N', 0.003194888178913738),
#   ('‘', 0.003194888178913738)],
#  '   C': [('H', 1.0)],
#  '  CH': [('A', 1.0)],
#  ' CHA': [('P', 1.0)],
#  'CHAP': [('T', 1.0)],
#  'HAPT': [('E', 1.0)],
#  'APTE': [('R', 1.0)],
#  'PTER': [(' ', 1.0)],
#  'TER ': [('I', 0.13157894736842105),
#   ('V', 0.10526315789473684),
#   ('X', 0.7631578947368421)],
#  'ER I': [(' ', 0.1), ('I', 0.4), ('V', 0.2), ('X', 0.2), ('.', 0.1)],
#  'R I ': [(' ', 1.0)],
#  ' I  ': [(' ', 1.0)],
#  'I   ': [(' ', 1.0)],
#  '   M': [('r', 0.25), ('a', 0.5), ('o', 0.125), ('i', 0.125)],
#  '  Mr': [('s', 1.0)],
#  ' Mrs': [('.', 0.9970760233918129), (' ', 0.0029239766081871343)],
#  'Mrs.': [(' ', 0.9306930693069307), ('\n', 0.06930693069306931)],
#  'rs. ': [('R', 0.14285714285714285),
#   ('A', 0.15207373271889402),
#   ('S', 0.08755760368663594),
#   ('Y', 0.004608294930875576),
#   ('I', 0.020737327188940093),
#   ('W', 0.0069124423963133645),
#   ('T', 0.06912442396313365),
#   ('H', 0.03456221198156682),
#   ('P', 0.013824884792626729),
#   ('B', 0.12672811059907835),
#   ('“', 0.01152073732718894),
#   ('D', 0.0069124423963133645),
#   ('N', 0.004608294930875576),
#   ('L', 0.28110599078341014),
#   ('M', 0.009216589861751152),
#   ('C', 0.01152073732718894),
#   ('O', 0.002304147465437788),
#   ('F', 0.002304147465437788),
#   ('E', 0.009216589861751152),
#   ('U', 0.002304147465437788)],
#  's. R': [('a', 0.9104477611940298),
#   ('i', 0.014925373134328358),
#   ('e', 0.029850746268656716),
#   ('u', 0.04477611940298507)],
#  '. Ra': [('c', 1.0)],
#  ' Rac': [('h', 1.0)],
#  'Rach': [('e', 1.0)],
#  'ache': [('l', 0.5465116279069767),
#   ('d', 0.12209302325581395),
#   (' ', 0.0755813953488372),
#   ('.', 0.005813953488372093),
#   ('\n', 0.01744186046511628),
#   ('r', 0.19186046511627908),
#   ('s', 0.03488372093023256),
#   ('-', 0.005813953488372093)],
#  'chel': [(' ', 0.6631578947368421),
#   ('’', 0.08421052631578947),
#   ('\n', 0.042105263157894736),
#   (',', 0.09473684210526316),
#   ('.', 0.08421052631578947),
#   (';', 0.010526315789473684),
#   ('o', 0.010526315789473684),
#   ('?', 0.010526315789473684)],
#  'hel ': [('L', 0.265625),
#   ('w', 0.15625),
#   ('f', 0.046875),
#   ('k', 0.015625),
#   ('s', 0.09375),
#   ('r', 0.03125),
#   ('u', 0.03125),
#   ('c', 0.046875),
#   ('p', 0.015625),
#   ('i', 0.078125),
#   ('d', 0.03125),
#   ('t', 0.046875),
#   ('e', 0.015625),
#   ('g', 0.015625),
#   ('a', 0.046875),
#   ('n', 0.015625),
#   ('b', 0.015625),
#   ('o', 0.015625),
#   ('M', 0.015625)],
#  'el L': [('y', 0.9444444444444444), ('a', 0.05555555555555555)],
#  'l Ly': [('n', 1.0)],
#  ' Lyn': [('d', 1.0)],
#  'Lynd': [('e', 1.0)],
#  'ynde': [(' ', 0.6339869281045751),
#   ('’', 0.11764705882352941),
#   ('-', 0.006535947712418301),
#   (',', 0.1111111111111111),
#   ('\n', 0.058823529411764705),
#   ('?', 0.0196078431372549),
#   ('.', 0.032679738562091505),
#   ('!', 0.013071895424836602),
#   (';', 0.006535947712418301)],
#  'nde ': [('I', 0.05102040816326531),
#   ('i', 0.04081632653061224),
#   ('l', 0.05102040816326531),
#   ('w', 0.12244897959183673),
#   ('d', 0.02040816326530612),
#   ('a', 0.08163265306122448),
#   ('s', 0.3673469387755102),
#   ('t', 0.07142857142857142),
#   ('y', 0.01020408163265306),
#   ('g', 0.030612244897959183),
#   ('r', 0.01020408163265306),
#   ('n', 0.01020408163265306),
#   ('k', 0.01020408163265306),
#   ('h', 0.04081632653061224),
#   ('c', 0.030612244897959183),
#   ('b', 0.01020408163265306),
#   ('m', 0.01020408163265306),
#   ('f', 0.01020408163265306),
#   ('p', 0.01020408163265306),
#   ('o', 0.01020408163265306)],
#  'de I': [('s', 0.6), ('’', 0.2), (' ', 0.2)],
#  'e Is': [(' ', 0.4166666666666667), ('l', 0.5833333333333334)],
#  ' Is ': [('S', 0.14285714285714285),
#   ('B', 0.09523809523809523),
#   ('P', 0.09523809523809523),
#   ('I', 0.09523809523809523),
#   ('F', 0.09523809523809523),
#   ('O', 0.19047619047619047),
#   ('D', 0.09523809523809523),
#   ('t', 0.09523809523809523),
#   ('i', 0.047619047619047616),
#   ('J', 0.047619047619047616)],
#  'Is S': [('u', 1.0)],
#  's Su': [('r', 0.625), ('n', 0.25), ('p', 0.125)],
#  ' Sur': [('p', 0.8333333333333334), ('e', 0.16666666666666666)],
#  'Surp': [('r', 1.0)],
#  'urpr': [('i', 1.0)],
#  'rpri': [('s', 1.0)],
#  'pris': [('e', 0.8333333333333334),
#   ('i', 0.13333333333333333),
#   ('o', 0.03333333333333333)],
#  'rise': [('d', 0.4166666666666667),
#   (',', 0.08333333333333333),
#   (' ', 0.2777777777777778),
#   ('\n', 0.027777777777777776),
#   ('s', 0.05555555555555555),
#   ('?', 0.08333333333333333),
#   ('.', 0.05555555555555555)],
#  'ised': [('\n', 0.20512820512820512),
#   (' ', 0.717948717948718),
#   ('_', 0.02564102564102564),
#   ('.', 0.02564102564102564),
#   (',', 0.02564102564102564)],
#  'sed\n': [(' ', 0.16666666666666666),
#   ('\n', 0.16666666666666666),
#   ('t', 0.2777777777777778),
#   ('h', 0.05555555555555555),
#   ('i', 0.05555555555555555),
#   ('b', 0.1111111111111111),
#   ('A', 0.05555555555555555),
#   ('M', 0.05555555555555555),
#   ('o', 0.05555555555555555)],
#  'ed\n ': [(' ', 1.0)],
#  'd\n  ': [(' ', 0.9), ('T', 0.1)],
#  'R II': [(' ', 0.25), ('I', 0.5), ('.', 0.25)],
#  ' II ': [(' ', 1.0)],
#  'II  ': [(' ', 1.0)],
#  '  Ma': [('t', 0.5), ('r', 0.5)],
#  ' Mat': [('t', 1.0)],
#  'Matt': [('h', 0.997229916897507), ('i', 0.002770083102493075)],
#  'atth': [('e', 1.0)],
#  'tthe': [('w', 1.0)],
#  'thew': [(' ', 0.5972222222222222),
#   (',', 0.15),
#   ('’', 0.06666666666666667),
#   ('\n', 0.05277777777777778),
#   ('.', 0.09722222222222222),
#   ('?', 0.022222222222222223),
#   ('”', 0.002777777777777778),
#   ('!', 0.008333333333333333),
#   ('-', 0.002777777777777778)],
#  'hew ': [('C', 0.11162790697674418),
#   ('I', 0.013953488372093023),
#   ('s', 0.07906976744186046),
#   ('a', 0.16279069767441862),
#   ('t', 0.05581395348837209),
#   ('j', 0.004651162790697674),
#   ('w', 0.13953488372093023),
#   ('h', 0.10697674418604651),
#   ('c', 0.04186046511627907),
#   ('e', 0.018604651162790697),
#   ('d', 0.037209302325581395),
#   ('b', 0.023255813953488372),
#   ('g', 0.023255813953488372),
#   ('i', 0.037209302325581395),
#   ('v', 0.004651162790697674),
#   ('r', 0.018604651162790697),
#   ('o', 0.018604651162790697),
#   ('l', 0.009302325581395349),
#   ('n', 0.018604651162790697),
#   ('m', 0.004651162790697674),
#   ('u', 0.009302325581395349),
#   ('‘', 0.004651162790697674),
#   ('p', 0.013953488372093023),
#   ('f', 0.03255813953488372),
#   ('k', 0.004651162790697674),
#   ('q', 0.004651162790697674)],
#  'ew C': [('u', 1.0)],
#  'w Cu': [('t', 1.0)],
#  ' Cut': [('h', 1.0)],
#  'Cuth': [('b', 1.0)],
#  'uthb': [('e', 1.0)],
#  'thbe': [('r', 1.0)],
#  'hber': [('t', 1.0)],
#  'bert': [(' ', 0.6397849462365591),
#   (',', 0.12365591397849462),
#   ('s', 0.016129032258064516),
#   ('’', 0.03763440860215054),
#   ('\n', 0.06989247311827956),
#   ('!', 0.016129032258064516),
#   ('?', 0.021505376344086023),
#   ('.', 0.05913978494623656),
#   ('-', 0.005376344086021506),
#   ('a', 0.005376344086021506),
#   (';', 0.005376344086021506)],
#  'ert ': [('I', 0.013888888888888888),
#   ('a', 0.09722222222222222),
#   ('p', 0.020833333333333332),
#   ('o', 0.05555555555555555),
#   ('h', 0.09027777777777778),
#   ('g', 0.013888888888888888),
#   ('s', 0.020833333333333332),
#   ('i', 0.08333333333333333),
#   ('w', 0.10416666666666667),
#   ('t', 0.027777777777777776),
#   ('f', 0.013888888888888888),
#   ('B', 0.3194444444444444),
#   ('r', 0.006944444444444444),
#   ('m', 0.020833333333333332),
#   ('c', 0.027777777777777776),
#   ('e', 0.006944444444444444),
#   ('l', 0.034722222222222224),
#   ('d', 0.006944444444444444),
#   ('n', 0.013888888888888888),
#   ('‘', 0.006944444444444444),
#   ('b', 0.013888888888888888)],
#  'rt I': [('s', 0.6666666666666666), ('\n', 0.3333333333333333)],
#  't Is': [(' ', 1.0)],
#  ' III': [(' ', 0.5), ('.', 0.5)],
#  'III ': [(' ', 1.0)],
#  ' Mar': [('i', 0.9667590027700831),
#   ('y', 0.018005540166204988),
#   ('c', 0.00554016620498615),
#   ('k', 0.0013850415512465374),
#   ('-', 0.0013850415512465374),
#   ('s', 0.0013850415512465374),
#   ('r', 0.0013850415512465374),
#   ('t', 0.004155124653739612)],
#  'Mari': [('l', 0.9988193624557261), ('t', 0.0011806375442739079)],
#  'aril': [('l', 0.9952941176470588), ('y', 0.004705882352941176)],
#  'rill': [('a', 0.9389567147613762),
#   ('.', 0.004439511653718091),
#   ('?', 0.0011098779134295228),
#   (' ', 0.014428412874583796),
#   ('s', 0.011098779134295227),
#   (',', 0.0022197558268590455),
#   ('i', 0.016648168701442843),
#   ('e', 0.005549389567147614),
#   ('-', 0.0011098779134295228),
#   ('\n', 0.0022197558268590455),
#   ('y', 0.0022197558268590455)],
#  'illa': [(' ', 0.41327124563445866),
#   ('\n', 0.020954598370197905),
#   ('’', 0.06286379511059371),
#   ('?', 0.04307334109429569),
#   (',', 0.25029103608847497),
#   ('.', 0.1839348079161816),
#   ('-', 0.008149010477299184),
#   ('g', 0.004656577415599534),
#   ('”', 0.002328288707799767),
#   (';', 0.0034924330616996507),
#   ('!', 0.005820721769499418),
#   ('r', 0.0011641443538998836)],
#  'lla ': [('C', 0.04132231404958678),
#   ('M', 0.02203856749311295),
#   ('a', 0.10192837465564739),
#   ('m', 0.01652892561983471),
#   ('s', 0.1349862258953168),
#   ('w', 0.15426997245179064),
#   ('h', 0.0881542699724518),
#   ('d', 0.0440771349862259),
#   ('o', 0.011019283746556474),
#   ('l', 0.05785123966942149),
#   ('c', 0.03856749311294766),
#   ('r', 0.03305785123966942),
#   ('p', 0.013774104683195593),
#   ('i', 0.049586776859504134),
#   ('g', 0.02203856749311295),
#   ('f', 0.046831955922865015),
#   ('t', 0.046831955922865015),
#   ('e', 0.013774104683195593),
#   ('I', 0.0027548209366391185),
#   ('b', 0.024793388429752067),
#   ('k', 0.011019283746556474),
#   ('u', 0.011019283746556474),
#   ('y', 0.0027548209366391185),
#   ('H', 0.0027548209366391185),
#   ('B', 0.0027548209366391185),
#   ('‘', 0.0027548209366391185),
#   ('G', 0.0027548209366391185)],
#  'la C': [('u', 1.0)],
#  'a Cu': [('t', 1.0)],
#  'R IV': [(' ', 0.5), ('.', 0.5)],
#  ' IV ': [(' ', 1.0)],
#  'IV  ': [(' ', 1.0)],
#  'V   ': [(' ', 1.0)],
#  '  Mo': [('r', 1.0)],
#  ' Mor': [('n', 0.5), ('r', 0.16666666666666666), ('e', 0.3333333333333333)],
#  'Morn': [('i', 1.0)],
#  'orni': [('n', 1.0)],
#  'rnin': [('g', 1.0)],
#  'ning': [(' ', 0.6525679758308157),
#   ('\n', 0.0634441087613293),
#   (',', 0.10574018126888217),
#   ('.', 0.10876132930513595),
#   ('s', 0.04229607250755287),
#   (';', 0.00906344410876133),
#   ('?', 0.006042296072507553),
#   ('-', 0.00906344410876133),
#   ('’', 0.0030211480362537764)],
#  'ing ': [('a', 0.14076484947111473),
#   ('t', 0.2306753458096013),
#   ('o', 0.0691619202603743),
#   ('C', 0.0032546786004882017),
#   ('“', 0.0008136696501220504),
#   ('i', 0.07119609438567942),
#   ('h', 0.06875508543531327),
#   ('p', 0.02115541090317331),
#   ('f', 0.04231082180634662),
#   ('m', 0.024410089503661515),
#   ('s', 0.05044751830756713),
#   ('b', 0.03295362082994304),
#   ('w', 0.04800650935720097),
#   ('u', 0.029292107404393815),
#   ('c', 0.019121236777868186),
#   ('r', 0.01627339300244101),
#   ('d', 0.021562245728234338),
#   ('e', 0.019934906427990236),
#   ('y', 0.010984540276647681),
#   ('n', 0.009764035801464606),
#   ('l', 0.012205044751830757),
#   ('I', 0.007729861676159479),
#   ('W', 0.006509357200976403),
#   ('q', 0.0020341741253051262),
#   ('v', 0.0052888527257933275),
#   ('g', 0.008950366151342554),
#   ('M', 0.007729861676159479),
#   ('A', 0.0040683482506102524),
#   ('L', 0.0004068348250610252),
#   ('_', 0.0008136696501220504),
#   ('j', 0.0020341741253051262),
#   ('R', 0.0004068348250610252),
#   ('k', 0.0020341741253051262),
#   ('B', 0.0008136696501220504),
#   ('‘', 0.0008136696501220504),
#   ('P', 0.0004068348250610252),
#   ('D', 0.0028478437754271765),
#   ('G', 0.0020341741253051262),
#   ('T', 0.0008136696501220504),
#   ('F', 0.0004068348250610252),
#   ('V', 0.0004068348250610252),
#   ('E', 0.0004068348250610252)],
#  'ng a': [('t', 0.13953488372093023),
#   (' ', 0.18087855297157623),
#   ('n', 0.21963824289405684),
#   ('w', 0.025839793281653745),
#   ('b', 0.11627906976744186),
#   ('f', 0.03617571059431524),
#   ('s', 0.11627906976744186),
#   ('\n', 0.01808785529715762),
#   ('d', 0.007751937984496124),
#   ('l', 0.06201550387596899),
#   ('p', 0.0103359173126615),
#   ('r', 0.0103359173126615),
#   ('i', 0.002583979328165375),
#   ('c', 0.01808785529715762),
#   ('m', 0.007751937984496124),
#   ('g', 0.025839793281653745),
#   ('u', 0.002583979328165375)],
#  'g at': [(' ', 0.9272727272727272),
#   ('\n', 0.05454545454545454),
#   ('t', 0.01818181818181818)],
#  ' at ': [('G', 0.06153846153846154),
#   ('Q', 0.009615384615384616),
#   ('h', 0.09807692307692308),
#   ('C', 0.026923076923076925),
#   ('t', 0.2826923076923077),
#   ('a', 0.13653846153846153),
#   ('p', 0.009615384615384616),
#   ('n', 0.015384615384615385),
#   ('l', 0.057692307692307696),
#   ('s', 0.01730769230769231),
#   ('B', 0.0057692307692307696),
#   ('m', 0.032692307692307694),
#   ('o', 0.051923076923076926),
#   ('e', 0.015384615384615385),
#   ('M', 0.019230769230769232),
#   ('c', 0.0057692307692307696),
#   ('A', 0.023076923076923078),
#   ('_', 0.0019230769230769232),
#   ('W', 0.0057692307692307696),
#   ('O', 0.0057692307692307696),
#   ('f', 0.021153846153846155),
#   ('y', 0.015384615384615385),
#   ('H', 0.0019230769230769232),
#   ('i', 0.04038461538461539),
#   ('P', 0.0057692307692307696),
#   ('d', 0.007692307692307693),
#   ('g', 0.0057692307692307696),
#   ('N', 0.0038461538461538464),
#   ('b', 0.0057692307692307696),
#   ('r', 0.0019230769230769232),
#   ('R', 0.0057692307692307696),
#   ('w', 0.0019230769230769232)],
#  'at G': [('r', 0.7619047619047619),
#   ('o', 0.047619047619047616),
#   ('i', 0.19047619047619047)],
#  't Gr': [('e', 1.0)],
#  'es\n ': [(' ', 1.0)],
#  's\n  ': [(' ', 1.0)],
#  'ER V': [(' ', 0.125), ('I', 0.75), ('.', 0.125)],
#  'R V ': [(' ', 1.0)],
#  ' V  ': [(' ', 1.0)],
#  '   A': [('n', 0.631578947368421), (' ', 0.3684210526315789)],
#  '  An': [('n', 0.7692307692307693),
#   (' ', 0.15384615384615385),
#   ('d', 0.07692307692307693)],
#  'nne’': [('s', 1.0)],
#  'ne’s': [(' ', 0.9516129032258065), ('\n', 0.04838709677419355)],
#  'e’s ': [('H', 0.014367816091954023),
#   ('B', 0.005747126436781609),
#   ('A', 0.008620689655172414),
#   ('I', 0.005747126436781609),
#   ('C', 0.005747126436781609),
#   ('L', 0.005747126436781609),
#   ('d', 0.022988505747126436),
#   ('h', 0.0603448275862069),
#   ('g', 0.07758620689655173),
#   ('p', 0.04310344827586207),
#   ('c', 0.040229885057471264),
#   ('s', 0.11494252873563218),
#   ('n', 0.07758620689655173),
#   ('u', 0.011494252873563218),
#   ('l', 0.02586206896551724),
#   ('r', 0.014367816091954023),
#   ('a', 0.13218390804597702),
#   ('o', 0.04310344827586207),
#   ('t', 0.07183908045977011),
#   ('j', 0.011494252873563218),
#   ('b', 0.05459770114942529),
#   ('w', 0.011494252873563218),
#   ('f', 0.04885057471264368),
#   ('e', 0.020114942528735632),
#   ('v', 0.008620689655172414),
#   ('i', 0.03735632183908046),
#   ('“', 0.0028735632183908046),
#   ('m', 0.011494252873563218),
#   ('_', 0.0028735632183908046),
#   ('y', 0.0028735632183908046),
#   ('q', 0.005747126436781609)],
#  '’s H': [('i', 0.4), ('o', 0.6)],
#  's Hi': [('s', 1.0)],
#  ' His': [('t', 0.18181818181818182), (' ', 0.8181818181818182)],
#  'Hist': [('o', 1.0)],
#  'isto': [('r', 1.0)],
#  'stor': [('y', 0.6097560975609756),
#   ('e', 0.15853658536585366),
#   ('m', 0.06097560975609756),
#   ('i', 0.15853658536585366),
#   (' ', 0.012195121951219513)],
#  'tory': [('\n', 0.06451612903225806),
#   (' ', 0.6774193548387096),
#   (',', 0.11290322580645161),
#   ('-', 0.03225806451612903),
#   ('.', 0.08064516129032258),
#   ('b', 0.03225806451612903)],
#  'ory\n': [(' ', 0.2), ('\n', 0.2), ('o', 0.2), ('a', 0.2), ('s', 0.2)],
#  'ry\n ': [(' ', 1.0)],
#  'y\n  ': [(' ', 1.0)],
#  'R VI': [(' ', 0.16666666666666666),
#   ('I', 0.6666666666666666),
#   ('.', 0.16666666666666666)],
#  ' VI ': [(' ', 1.0)],
#  'VI  ': [(' ', 1.0)],
#  'la M': [('a', 1.0)],
#  'a Ma': [('k', 0.25), ('y', 0.75)],
#  ' Mak': [('e', 1.0)],
#  'Make': [('s', 1.0)],
#  'akes': [(' ', 0.78125),
#   ('\n', 0.046875),
#   ('!', 0.015625),
#   (',', 0.0625),
#   ('.', 0.0625),
#   ('?', 0.015625),
#   ('-', 0.015625)],
#  'kes ': [('U', 0.038461538461538464),
#   ('o', 0.038461538461538464),
#   ('_', 0.019230769230769232),
#   ('t', 0.17307692307692307),
#   ('m', 0.25),
#   ('a', 0.057692307692307696),
#   ('f', 0.019230769230769232),
#   ('s', 0.019230769230769232),
#   ('b', 0.019230769230769232),
#   ('I', 0.019230769230769232),
#   ('h', 0.057692307692307696),
#   ('i', 0.11538461538461539),
#   ('p', 0.019230769230769232),
#   ('A', 0.019230769230769232),
#   ('l', 0.019230769230769232),
#   ('u', 0.057692307692307696),
#   ('y', 0.038461538461538464),
#   ('e', 0.019230769230769232)],
#  'es U': [('p', 1.0)],
#  's Up': [(' ', 1.0)],
#  ' Up ': [('H', 0.5), ('a', 0.5)],
#  'Up H': [('e', 1.0)],
#  'p He': [('r', 1.0)],
#  ' Her': [(' ', 0.6981132075471698),
#   ('e', 0.20754716981132076),
#   ('\n', 0.07547169811320754),
#   ('a', 0.018867924528301886)],
#  'Her ': [('M', 0.05),
#   ('P', 0.1),
#   ('c', 0.025),
#   ('f', 0.15),
#   ('h', 0.175),
#   ('n', 0.075),
#   ('s', 0.05),
#   ('t', 0.05),
#   ('m', 0.075),
#   ('w', 0.05),
#   ('i', 0.075),
#   ('e', 0.025),
#   ('r', 0.05),
#   ('l', 0.025),
#   ('k', 0.025)],
#  'er M': [('i', 0.21428571428571427),
#   ('e', 0.14285714285714285),
#   ('o', 0.07142857142857142),
#   ('a', 0.42857142857142855),
#   ('r', 0.14285714285714285)],
#  'r Mi': [('n', 0.4444444444444444), ('s', 0.5555555555555556)],
#  ' Min': [('d', 0.20833333333333334), ('n', 0.6666666666666666), ('e', 0.125)],
#  'Mind': [('\n', 0.3333333333333333), (' ', 0.6666666666666666)],
#  'ind\n': [(' ', 0.07692307692307693),
#   ('h', 0.07692307692307693),
#   ('t', 0.15384615384615385),
#   ('\n', 0.07692307692307693),
#   ('g', 0.07692307692307693),
#   ('l', 0.07692307692307693),
#   ('o', 0.3076923076923077),
#   ('i', 0.07692307692307693),
#   ('m', 0.07692307692307693)],
#  'nd\n ': [(' ', 1.0)],
#  ' VII': [(' ', 0.25), ('I', 0.5), ('.', 0.25)],
#  'VII ': [(' ', 1.0)],
#  'ne S': [('a', 0.08), ('h', 0.86), ('u', 0.02), ('e', 0.04)],
#  'e Sa': [('y', 0.08333333333333333),
#   ('n', 0.75),
#   ('t', 0.125),
#   ('m', 0.041666666666666664)],
#  ' Say': [('s', 0.6666666666666666), (' ', 0.3333333333333333)],
#  'Says': [(' ', 1.0)],
#  'ays ': [('H', 0.008695652173913044),
#   ('d', 0.017391304347826087),
#   ('s', 0.1608695652173913),
#   ('h', 0.09565217391304348),
#   ('t', 0.16521739130434782),
#   ('a', 0.04782608695652174),
#   ('f', 0.02608695652173913),
#   ('b', 0.043478260869565216),
#   ('i', 0.08260869565217391),
#   ('c', 0.017391304347826087),
#   ('k', 0.013043478260869565),
#   ('l', 0.030434782608695653),
#   ('w', 0.0782608695652174),
#   ('e', 0.013043478260869565),
#   ('M', 0.008695652173913044),
#   ('o', 0.02608695652173913),
#   ('p', 0.030434782608695653),
#   ('m', 0.030434782608695653),
#   ('y', 0.021739130434782608),
#   ('r', 0.008695652173913044),
#   ('I', 0.04782608695652174),
#   ('C', 0.004347826086956522),
#   ('g', 0.017391304347826087),
#   ('E', 0.004347826086956522)],
#  'ys H': [('e', 1.0)],
#  's He': [('r', 0.6666666666666666), ('p', 0.3333333333333333)],
#  'er P': [('r', 0.5), ('u', 0.5)],
#  'r Pr': [('a', 1.0)],
#  ' Pra': [('y', 1.0)],
#  'Pray': [('e', 1.0)],
#  'raye': [('r', 0.84), ('d', 0.16)],
#  'ayer': [('s', 0.4166666666666667),
#   (' ', 0.4166666666666667),
#   ('.', 0.08333333333333333),
#   (',', 0.041666666666666664),
#   ('\n', 0.041666666666666664)],
#  'yers': [('\n', 0.1), (' ', 0.45), (',', 0.1), ('?', 0.05), ('.', 0.3)],
#  'ers\n': [(' ', 0.1),
#   ('\n', 0.1),
#   ('g', 0.1),
#   ('l', 0.1),
#   ('I', 0.1),
#   ('o', 0.1),
#   ('i', 0.1),
#   ('a', 0.2),
#   ('t', 0.1)],
#  'rs\n ': [(' ', 1.0)],
#  'VIII': [(' ', 0.5), ('.', 0.5)],
#  '’s B': [('r', 0.2222222222222222),
#   ('a', 0.1111111111111111),
#   ('u', 0.6666666666666666)],
#  's Br': [('i', 1.0)],
#  ' Bri': [('n', 0.15384615384615385),
#   ('g', 0.7692307692307693),
#   ('t', 0.07692307692307693)],
#  'Brin': [('g', 1.0)],
#  'ring': [('i', 0.08130081300813008),
#   ('s', 0.04065040650406504),
#   ('e', 0.02032520325203252),
#   (' ', 0.6788617886178862),
#   ('.', 0.06097560975609756),
#   ('\n', 0.04878048780487805),
#   ('l', 0.028455284552845527),
#   (';', 0.0040650406504065045),
#   (',', 0.028455284552845527),
#   ('?', 0.0040650406504065045),
#   ('-', 0.0040650406504065045)],
#  'ingi': [('n', 1.0)],
#  'ngin': [('g', 0.96), ('e', 0.04)],
#  'ging': [('-', 0.028169014084507043),
#   (' ', 0.7464788732394366),
#   ('\n', 0.07042253521126761),
#   ('h', 0.07042253521126761),
#   (',', 0.014084507042253521),
#   ('e', 0.014084507042253521),
#   ('l', 0.014084507042253521),
#   ('.', 0.04225352112676056)],
#  'ing-': [('U', 0.034482758620689655),
#   ('-', 0.5862068965517241),
#   ('u', 0.034482758620689655),
#   ('r', 0.13793103448275862),
#   ('g', 0.034482758620689655),
#   ('h', 0.10344827586206896),
#   ('m', 0.034482758620689655),
#   ('p', 0.034482758620689655)],
#  'ng-U': [('p', 1.0)],
#  'g-Up': [(' ', 1.0)],
#  '-Up ': [('I', 1.0)],
#  'Up I': [('s', 1.0)],
#  'p Is': [(' ', 1.0)],
#  'Is B': [('e', 1.0)],
#  's Be': [('g', 0.6666666666666666), ('r', 0.3333333333333333)],
#  ' Beg': [('u', 1.0)],
#  'Begu': [('n', 1.0)],
#  'egun': [('\n', 0.375), (' ', 0.625)],
#  'gun\n': [(' ', 0.3333333333333333),
#   ('\n', 0.3333333333333333),
#   ('t', 0.3333333333333333)],
#  'un\n ': [(' ', 1.0)],
#  'n\n  ': [(' ', 0.8), ('A', 0.2)],
#  'R IX': [(' ', 0.5), ('.', 0.5)],
#  ' IX ': [(' ', 1.0)],
#  'IX  ': [(' ', 1.0)],
#  'X   ': [(' ', 1.0)],
#  'Is P': [('r', 1.0)],
#  's Pr': [('o', 0.75), ('a', 0.25)],
#  ' Pro': [('p', 0.15384615384615385),
#   ('m', 0.23076923076923078),
#   ('v', 0.46153846153846156),
#   ('b', 0.07692307692307693),
#   ('f', 0.07692307692307693)],
#  'Prop': [('e', 1.0)],
#  'rope': [('r', 0.9090909090909091),
#   (' ', 0.045454545454545456),
#   ('s', 0.045454545454545456)],
#  'oper': [('l', 0.4), ('.', 0.1), ('\n', 0.1), (' ', 0.4)],
#  'perl': [('y', 1.0)],
#  'erly': [(' ', 0.4146341463414634),
#   ('.', 0.3902439024390244),
#   (',', 0.0975609756097561),
#   ('\n', 0.07317073170731707),
#   ('?', 0.024390243902439025)],
#  'rly ': [('H', 0.028169014084507043),
#   ('J', 0.014084507042253521),
#   ('c', 0.028169014084507043),
#   ('d', 0.09859154929577464),
#   ('b', 0.09859154929577464),
#   ('l', 0.04225352112676056),
#   ('h', 0.028169014084507043),
#   ('a', 0.11267605633802817),
#   ('w', 0.09859154929577464),
#   ('i', 0.07042253521126761),
#   ('k', 0.014084507042253521),
#   ('p', 0.028169014084507043),
#   ('f', 0.09859154929577464),
#   ('r', 0.028169014084507043),
#   ('g', 0.04225352112676056),
#   ('e', 0.028169014084507043),
#   ('s', 0.04225352112676056),
#   ('m', 0.014084507042253521),
#   ('o', 0.028169014084507043),
#   ('t', 0.04225352112676056),
#   ('v', 0.014084507042253521)],
#  'ly H': [('o', 0.5), ('e', 0.5)],
#  'y Ho': [('r', 0.6666666666666666), ('m', 0.3333333333333333)],
#  ' Hor': [('r', 1.0)],
#  'Horr': [('i', 1.0)],
#  'orri': [('f', 0.13157894736842105),
#   ('s', 0.02631578947368421),
#   ('d', 0.23684210526315788),
#   ('b', 0.34210526315789475),
#   ('e', 0.2631578947368421)],
#  'rrif': [('i', 1.0)],
#  'rifi': [('e', 0.6153846153846154), ('c', 0.38461538461538464)],
#  'ifie': [('d', 1.0)],
#  'fied': [('\n', 0.13333333333333333),
#   (' ', 0.6666666666666666),
#   (',', 0.1),
#   ('.', 0.1)],
#  'ied\n': [(' ', 0.07142857142857142),
#   ('\n', 0.07142857142857142),
#   ('t', 0.35714285714285715),
#   ('h', 0.07142857142857142),
#   ('a', 0.2857142857142857),
#   ('c', 0.07142857142857142),
#   ('T', 0.07142857142857142)],
#  'ER X': [(' ', 0.017241379310344827),
#   ('I', 0.1724137931034483),
#   ('V', 0.13793103448275862),
#   ('X', 0.6551724137931034),
#   ('.', 0.017241379310344827)],
#  'R X ': [(' ', 1.0)],
#  ' X  ': [(' ', 1.0)],
#  '’s A': [('p', 0.5), ('n', 0.5)],
#  's Ap': [('o', 1.0)],
#  ' Apo': [('l', 1.0)],
#  'Apol': [('o', 1.0)],
#  'polo': [('g', 1.0)],
#  'olog': [('y', 0.35), ('e', 0.1), ('i', 0.55)],
#  'logy': [('\n', 0.42857142857142855), (' ', 0.5714285714285714)],
#  'ogy\n': [(' ', 0.3333333333333333),
#   ('\n', 0.3333333333333333),
#   ('w', 0.3333333333333333)],
#  'gy\n ': [(' ', 1.0)],
#  'R XI': [(' ', 0.1), ('I', 0.4), ('V', 0.2), ('X', 0.2), ('.', 0.1)],
#  ' XI ': [(' ', 1.0)],
#  'XI  ': [(' ', 1.0)],
#  '’s I': [('m', 0.5), (' ', 0.5)],
#  's Im': [('p', 1.0)],
#  ' Imp': [('r', 1.0)],
#  'Impr': [('e', 1.0)],
#  'mpre': [('s', 0.5555555555555556), ('h', 0.4444444444444444)],
#  'pres': [('s', 0.4725274725274725),
#   ('e', 0.5054945054945055),
#   ('c', 0.01098901098901099),
#   ('u', 0.01098901098901099)],
#  'ress': [('i', 0.22784810126582278),
#   ('e', 0.31645569620253167),
#   (' ', 0.2088607594936709),
#   ('.', 0.08860759493670886),
#   ('-', 0.02531645569620253),
#   ('\n', 0.02531645569620253),
#   (',', 0.0759493670886076),
#   ('l', 0.006329113924050633),
#   ('’', 0.006329113924050633),
#   (';', 0.006329113924050633),
#   ('m', 0.006329113924050633),
#   ('y', 0.006329113924050633)],
#  'essi': [('o', 0.5285714285714286),
#   ('n', 0.3142857142857143),
#   ('v', 0.05714285714285714),
#   ('m', 0.04285714285714286),
#   ('b', 0.014285714285714285),
#   ('e', 0.02857142857142857),
#   ('t', 0.014285714285714285)],
#  'ssio': [('n', 1.0)],
#  'sion': [('s', 0.10526315789473684),
#   ('\n', 0.07368421052631578),
#   ('.', 0.09473684210526316),
#   ('a', 0.21052631578947367),
#   (' ', 0.3473684210526316),
#   (',', 0.06315789473684211),
#   ('-', 0.021052631578947368),
#   (';', 0.021052631578947368),
#   (':', 0.010526315789473684),
#   ('?', 0.010526315789473684),
#   ('e', 0.031578947368421054),
#   ('l', 0.010526315789473684)],
#  'ions': [(' ', 0.5614035087719298),
#   ('.', 0.19298245614035087),
#   ('\n', 0.06140350877192982),
#   ('?', 0.008771929824561403),
#   (',', 0.12280701754385964),
#   ('’', 0.008771929824561403),
#   (';', 0.008771929824561403),
#   ('h', 0.02631578947368421),
#   ('-', 0.008771929824561403)],
#  'ons ': [('o', 0.17525773195876287),
#   ('A', 0.010309278350515464),
#   ('a', 0.24742268041237114),
#   ('c', 0.020618556701030927),
#   ('t', 0.1134020618556701),
#   ('h', 0.061855670103092786),
#   ('r', 0.010309278350515464),
#   ('b', 0.030927835051546393),
#   ('w', 0.12371134020618557),
#   ('f', 0.05154639175257732),
#   ('i', 0.041237113402061855),
#   ('g', 0.010309278350515464),
#   ('M', 0.010309278350515464),
#   ('p', 0.010309278350515464),
#   ('n', 0.010309278350515464),
#   ('j', 0.010309278350515464),
#   ('s', 0.041237113402061855),
#   ('m', 0.010309278350515464),
#   ('e', 0.010309278350515464)],
#  'ns o': [('f', 0.75),
#   ('n', 0.14285714285714285),
#   ('u', 0.07142857142857142),
#   ('v', 0.03571428571428571)],
#  's of': [(' ', 0.8877551020408163),
#   ('t', 0.023809523809523808),
#   ('\n', 0.0782312925170068),
#   ('f', 0.01020408163265306)],
#  'of S': [('u', 0.10344827586206896),
#   ('p', 0.10344827586206896),
#   ('t', 0.034482758620689655),
#   ('h', 0.6896551724137931),
#   ('e', 0.034482758620689655),
#   ('c', 0.034482758620689655)],
#  'f Su': [('n', 0.6666666666666666), ('p', 0.3333333333333333)],
#  ' Sun': [('d', 1.0)],
#  'Sund': [('a', 1.0)],
#  'unda': [('y', 0.8928571428571429),
#   ('n', 0.05357142857142857),
#   ('u', 0.017857142857142856),
#   ('t', 0.03571428571428571)],
#  'nday': [(' ', 0.55),
#   ('-', 0.25),
#   (',', 0.06666666666666667),
#   ('\n', 0.06666666666666667),
#   ('.', 0.05),
#   ('s', 0.016666666666666666)],
#  'day ': [('S', 0.0078125),
#   ('d', 0.015625),
#   ('b', 0.0703125),
#   ('o', 0.0625),
#   ('I', 0.0234375),
#   ('a', 0.1953125),
#   ('w', 0.078125),
#   ('s', 0.078125),
#   ('y', 0.015625),
#   ('t', 0.1015625),
#   ('i', 0.0703125),
#   ('A', 0.015625),
#   ('e', 0.0390625),
#   ('m', 0.0390625),
#   ('l', 0.0390625),
#   ('n', 0.0390625),
#   ('M', 0.015625),
#   ('g', 0.015625),
#   ('p', 0.03125),
#   ('c', 0.015625),
#   ('D', 0.015625),
#   ('f', 0.015625)],
#  'ay S': [('c', 1.0)],
#  'y Sc': [('h', 1.0)],
#  ' Sch': [('o', 1.0)],
#  'Scho': [('o', 1.0)],
#  'choo': [('l', 0.9886363636363636), ('s', 0.011363636363636364)],
#  'hool': [('\n', 0.05747126436781609),
#   (' ', 0.5287356321839081),
#   (',', 0.05172413793103448),
#   ('i', 0.005747126436781609),
#   ('m', 0.017241379310344827),
#   ('.', 0.19540229885057472),
#   ('?', 0.017241379310344827),
#   (';', 0.011494252873563218),
#   ('h', 0.034482758620689655),
#   ('b', 0.011494252873563218),
#   ('w', 0.017241379310344827),
#   ('g', 0.017241379310344827),
#   ('-', 0.011494252873563218),
#   ('f', 0.005747126436781609),
#   ('s', 0.017241379310344827)],
#  'ool\n': [(' ', 0.09090909090909091),
#   ('a', 0.18181818181818182),
#   ('w', 0.18181818181818182),
#   ('\n', 0.09090909090909091),
#   ('t', 0.09090909090909091),
#   ('c', 0.18181818181818182),
#   ('o', 0.09090909090909091),
#   ('y', 0.09090909090909091)],
#  'ol\n ': [(' ', 1.0)],
#  'l\n  ': [(' ', 1.0)],
#  ' XII': [(' ', 0.25), ('I', 0.5), ('.', 0.25)],
#  'XII ': [(' ', 1.0)],
#  '  A ': [('S', 0.14285714285714285),
#   ('T', 0.14285714285714285),
#   ('N', 0.2857142857142857),
#   ('C', 0.14285714285714285),
#   ('G', 0.14285714285714285),
#   ('Q', 0.14285714285714285)],
#  ' A S': [('o', 1.0)],
#  'A So': [('l', 1.0)],
#  ' Sol': [('e', 1.0)],
#  'Sole': [('m', 1.0)],
#  'olem': [('n', 1.0)],
#  'lemn': [(' ', 0.36), ('i', 0.08), ('l', 0.48), (',', 0.08)],
#  'emn ': [('V', 0.2222222222222222),
#   ('g', 0.1111111111111111),
#   ('f', 0.1111111111111111),
#   ('t', 0.3333333333333333),
#   ('v', 0.1111111111111111),
#   ('o', 0.1111111111111111)],
#  'mn V': [('o', 1.0)],
#  'n Vo': [('w', 1.0)],
#  ' Vow': [(' ', 0.5), ('.', 0.25), ('”', 0.25)],
#  'Vow ': [('a', 1.0)],
#  'ow a': [('n', 0.5185185185185185),
#   (' ', 0.13580246913580246),
#   ('r', 0.04938271604938271),
#   ('b', 0.07407407407407407),
#   ('l', 0.024691358024691357),
#   ('t', 0.037037037037037035),
#   ('f', 0.04938271604938271),
#   ('s', 0.08641975308641975),
#   ('u', 0.012345679012345678),
#   ('\n', 0.012345679012345678)],
#  'w an': [('d', 0.8518518518518519),
#   ('o', 0.012345679012345678),
#   ('y', 0.12345679012345678),
#   (' ', 0.012345679012345678)],
#  ' and': [(' ', 0.9134318103744418),
#   ('\n', 0.08107179663345929),
#   (',', 0.0048093438680865686),
#   ('”', 0.00034352456200618345),
#   ('-', 0.00034352456200618345)],
#  'and ': [('P', 0.0016655562958027982),
#   ('a', 0.05862758161225849),
#   ('H', 0.0006662225183211193),
#   ('V', 0.0033311125916055963),
#   ('R', 0.0073284477015323115),
#   ('t', 0.13557628247834777),
#   ('l', 0.029980013324450366),
#   ('c', 0.03431045969353764),
#   ('d', 0.028980679546968688),
#   ('w', 0.06895403064623584),
#   ('o', 0.017321785476349102),
#   ('F', 0.000999333777481679),
#   ('k', 0.006662225183211193),
#   ('s', 0.10459693537641572),
#   ('b', 0.03164556962025317),
#   ('M', 0.031978680879413725),
#   ('u', 0.009660226515656229),
#   ('h', 0.06029313790806129),
#   ('f', 0.03231179213857428),
#   ('I', 0.07295136575616255),
#   ('n', 0.023984010659560292),
#   ('p', 0.03397734843437708),
#   ('i', 0.03530979347101932),
#   ('r', 0.020986009327115255),
#   ('m', 0.02764823451032645),
#   ('y', 0.018654230512991338),
#   ('e', 0.018654230512991338),
#   ('g', 0.023317788141239172),
#   ('v', 0.003997335109926716),
#   ('J', 0.010326449033977348),
#   ('A', 0.011992005329780146),
#   ('B', 0.0013324450366422385),
#   ('‘', 0.0016655562958027982),
#   ('q', 0.0013324450366422385),
#   ('S', 0.0006662225183211193),
#   ('D', 0.009993337774816789),
#   ('W', 0.0013324450366422385),
#   ('C', 0.002331778814123917),
#   ('G', 0.005329780146568954),
#   ('j', 0.002664890073284477),
#   ('E', 0.000999333777481679),
#   ('L', 0.0013324450366422385),
#   ('Y', 0.0006662225183211193),
#   ('_', 0.00033311125916055963),
#   ('“', 0.0013324450366422385),
#   ('T', 0.00033311125916055963),
#   ('K', 0.0006662225183211193),
#   ('z', 0.0006662225183211193),
#   ('N', 0.00033311125916055963)],
#  'nd P': [('r', 0.8), ('e', 0.2)],
#  'd Pr': [('o', 0.4), ('i', 0.6)],
#  'Prom': [('i', 0.75), ('o', 0.25)],
#  'romi': [('s', 1.0)],
#  'omis': [('e', 0.8787878787878788), ('i', 0.12121212121212122)],
#  'mise': [('\n', 0.045454545454545456),
#   ('.', 0.09090909090909091),
#   ('d', 0.38636363636363635),
#   ('r', 0.3409090909090909),
#   ('s', 0.022727272727272728),
# ...
#   ('’', 0.6666666666666666),
#   (' ', 0.09259259259259259),
#   ('.', 0.07407407407407407),
#   (',', 0.037037037037037035),
#   (';', 0.018518518518518517),
#   ('”', 0.018518518518518517),
#   ('l', 0.018518518518518517)],
#  'eens': [(' ', 0.6363636363636364),
#   ('.', 0.18181818181818182),
#   (',', 0.18181818181818182)],
#  'ens ': [('C', 0.13333333333333333),
#   ('a', 0.2),
#   ('f', 0.06666666666666667),
#   ('t', 0.13333333333333333),
#   ('o', 0.2),
#   ('m', 0.06666666666666667),
#   ('c', 0.06666666666666667),
#   ('d', 0.06666666666666667),
#   ('w', 0.06666666666666667)],
#  'ns C': [('l', 1.0)],
#  's Cl': [('a', 1.0)],
#  ' Cla': [('s', 0.5833333333333334), ('r', 0.16666666666666666), ('y', 0.25)],
#  'Clas': [('s', 1.0)],
#  'lass': [(' ', 0.5205479452054794),
#   ('i', 0.0136986301369863),
#   ('.', 0.1095890410958904),
#   ('r', 0.0136986301369863),
#   ('\n', 0.0136986301369863),
#   (',', 0.1095890410958904),
#   ('f', 0.0273972602739726),
#   ('e', 0.1643835616438356),
#   (';', 0.0273972602739726)],
#  'ass ': [('I', 0.03278688524590164),
#   ('L', 0.04918032786885246),
#   ('o', 0.06557377049180328),
#   ('d', 0.03278688524590164),
#   ('w', 0.04918032786885246),
#   ('a', 0.22950819672131148),
#   ('t', 0.16393442622950818),
#   ('f', 0.06557377049180328),
#   ('h', 0.04918032786885246),
#   ('b', 0.01639344262295082),
#   ('m', 0.01639344262295082),
#   ('i', 0.04918032786885246),
#   ('g', 0.03278688524590164),
#   ('l', 0.13114754098360656),
#   ('r', 0.01639344262295082)],
#  'ss I': [('s', 0.2857142857142857),
#   (' ', 0.42857142857142855),
#   ('’', 0.2857142857142857)],
#  's Is': [(' ', 0.5), ('l', 0.5)],
#  'Is O': [('r', 0.5), ('u', 0.5)],
#  's Or': [('g', 1.0)],
#  ' Org': [('a', 1.0)],
#  'Orga': [('n', 1.0)],
#  'rgan': [('i', 0.4166666666666667),
#   (' ', 0.08333333333333333),
#   ('d', 0.4166666666666667),
#   ('.', 0.08333333333333333)],
#  'gani': [('z', 1.0)],
#  'aniz': [('e', 1.0)],
#  'nize': [('d', 0.8888888888888888), (' ', 0.1111111111111111)],
#  'ized': [('\n', 0.10714285714285714),
#   (' ', 0.7857142857142857),
#   ('.', 0.03571428571428571),
#   (';', 0.03571428571428571),
#   (',', 0.03571428571428571)],
#  'zed\n': [(' ', 0.2), ('i', 0.2), ('a', 0.2), ('\n', 0.2), ('u', 0.2)],
#  'XXXI': [(' ', 0.125), ('I', 0.5), ('V', 0.25), ('.', 0.125)],
#  '   W': [('h', 0.5), ('a', 0.5)],
#  '  Wh': [('e', 1.0)],
#  ' Whe': [('r', 0.1643835616438356), ('n', 0.8356164383561644)],
#  'Wher': [('e', 1.0)],
#  'here': [(' ', 0.6511627906976745),
#   ('f', 0.007267441860465116),
#   ('o', 0.010174418604651164),
#   ('?', 0.015988372093023256),
#   ('\n', 0.024709302325581394),
#   ('’', 0.11046511627906977),
#   ('.', 0.04796511627906977),
#   (',', 0.07848837209302326),
#   ('a', 0.005813953488372093),
#   ('”', 0.0029069767441860465),
#   ('!', 0.005813953488372093),
#   ('u', 0.005813953488372093),
#   ('d', 0.007267441860465116),
#   ('-', 0.015988372093023256),
#   ('i', 0.00436046511627907),
#   ('t', 0.0014534883720930232),
#   ('b', 0.0014534883720930232),
#   ('s', 0.0014534883720930232),
#   ('v', 0.0014534883720930232)],
#  'ere ': [('t', 0.12041884816753927),
#   ('a', 0.17670157068062828),
#   ('w', 0.17670157068062828),
#   ('o', 0.0549738219895288),
#   ('h', 0.03534031413612566),
#   ('i', 0.0968586387434555),
#   ('s', 0.07984293193717278),
#   ('b', 0.02356020942408377),
#   ('e', 0.013089005235602094),
#   ('p', 0.011780104712041885),
#   ('m', 0.020942408376963352),
#   ('c', 0.01832460732984293),
#   ('g', 0.011780104712041885),
#   ('f', 0.02356020942408377),
#   ('d', 0.024869109947643978),
#   ('y', 0.006544502617801047),
#   ('n', 0.0274869109947644),
#   ('r', 0.015706806282722512),
#   ('_', 0.002617801047120419),
#   ('u', 0.010471204188481676),
#   ('A', 0.003926701570680628),
#   ('l', 0.010471204188481676),
#   ('j', 0.003926701570680628),
#   ('v', 0.003926701570680628),
#   ('K', 0.0013089005235602095),
#   ('q', 0.002617801047120419),
#   ('D', 0.0013089005235602095),
#   ('M', 0.007853403141361256),
#   ('I', 0.007853403141361256),
#   ('“', 0.0013089005235602095),
#   ('S', 0.0013089005235602095),
#   ('R', 0.0013089005235602095),
#   ('G', 0.0013089005235602095)],
#  're t': [('h', 0.6074766355140186),
#   ('o', 0.2570093457943925),
#   ('w', 0.03271028037383177),
#   ('e', 0.028037383177570093),
#   ('a', 0.018691588785046728),
#   ('i', 0.028037383177570093),
#   ('r', 0.028037383177570093)],
#  'e th': [('e', 0.453125),
#   ('r', 0.040364583333333336),
#   ('a', 0.24739583333333334),
#   ('o', 0.09114583333333333),
#   ('i', 0.1640625),
#   ('y', 0.0013020833333333333),
#   ('u', 0.0013020833333333333),
#   ('w', 0.0013020833333333333)],
#  'he B': [('r', 0.10344827586206896),
#   ('e', 0.20689655172413793),
#   ('a', 0.41379310344827586),
#   ('i', 0.2413793103448276),
#   ('l', 0.034482758620689655)],
#  'e Br': [('o', 0.6666666666666666), ('i', 0.3333333333333333)],
#  ' Bro': [('o', 1.0)],
#  'Broo': [('k', 1.0)],
#  'rook': [(' ', 0.6511627906976745),
#   ('\n', 0.046511627906976744),
#   ('s', 0.046511627906976744),
#   (',', 0.06976744186046512),
#   ('.', 0.13953488372093023),
#   (';', 0.023255813953488372),
#   ('e', 0.023255813953488372)],
#  'ok a': [('n', 0.18518518518518517),
#   ('t', 0.5308641975308642),
#   (' ', 0.09876543209876543),
#   ('f', 0.08641975308641975),
#   ('s', 0.04938271604938271),
#   ('l', 0.024691358024691357),
#   ('w', 0.012345679012345678),
#   ('\n', 0.012345679012345678)],
#  'k an': [('d', 0.9393939393939394),
#   ('y', 0.045454545454545456),
#   (' ', 0.015151515151515152)],
#  'nd R': [('i', 0.08333333333333333), ('u', 0.9166666666666666)],
#  'd Ri': [('v', 1.0)],
#  ' Riv': [('e', 0.9166666666666666), ('a', 0.08333333333333333)],
#  'Rive': [('r', 1.0)],
#  'iver': [(' ', 0.5294117647058824),
#   ('.', 0.08823529411764706),
#   (',', 0.029411764705882353),
#   ('i', 0.08823529411764706),
#   ('e', 0.17647058823529413),
#   ('s', 0.058823529411764705),
#   ('y', 0.029411764705882353)],
#  'ver ': [('M', 0.0053404539385847796),
#   ('t', 0.20160213618157544),
#   ('b', 0.06542056074766354),
#   ('a', 0.09212283044058744),
#   ('s', 0.13618157543391188),
#   ('i', 0.06008010680907877),
#   ('o', 0.017356475300400534),
#   ('d', 0.029372496662216287),
#   ('w', 0.049399198931909215),
#   ('h', 0.1041388518024032),
#   ('_', 0.0026702269692923898),
#   ('m', 0.03871829105473965),
#   ('e', 0.01335113484646195),
#   ('r', 0.01335113484646195),
#   ('y', 0.01335113484646195),
#   ('c', 0.02403204272363151),
#   ('I', 0.006675567423230975),
#   ('g', 0.022696929238985315),
#   ('L', 0.0013351134846461949),
#   ('n', 0.00801068090787717),
#   ('l', 0.021361815754339118),
#   ('k', 0.009345794392523364),
#   ('B', 0.0013351134846461949),
#   ('p', 0.009345794392523364),
#   ('A', 0.0053404539385847796),
#   ('q', 0.0026702269692923898),
#   ('f', 0.036048064085447265),
#   ('W', 0.0013351134846461949),
#   ('u', 0.004005340453938585),
#   ('D', 0.0013351134846461949),
#   ('v', 0.0013351134846461949),
#   ('G', 0.0013351134846461949)],
#  'r Me': [('e', 1.0)],
#  ' Mee': [('t', 1.0)],
#  'Meet': [('\n', 1.0)],
#  'eet\n': [(' ', 0.3333333333333333),
#   ('\n', 0.3333333333333333),
#   ('s', 0.3333333333333333)],
#  'et\n ': [(' ', 1.0)],
#  'he P': [('a', 0.2222222222222222),
#   ('e', 0.1111111111111111),
#   ('r', 0.5555555555555556),
#   ('i', 0.1111111111111111)],
#  'e Pa': [('s', 1.0)],
#  ' Pas': [('s', 1.0)],
#  'Pass': [(' ', 1.0)],
#  'ss L': [('i', 0.75), ('u', 0.25)],
#  ' Lis': [('t', 1.0)],
#  'List': [(' ', 0.6666666666666666), ('e', 0.3333333333333333)],
#  'ist ': [('I', 0.11538461538461539),
#   ('a', 0.15384615384615385),
#   ('B', 0.038461538461538464),
#   ('r', 0.07692307692307693),
#   ('t', 0.038461538461538464),
#   ('d', 0.038461538461538464),
#   ('i', 0.07692307692307693),
#   ('w', 0.19230769230769232),
#   ('e', 0.038461538461538464),
#   ('u', 0.038461538461538464),
#   ('o', 0.07692307692307693),
#   ('l', 0.038461538461538464),
#   ('c', 0.07692307692307693)],
#  'st I': [('s', 0.2), (' ', 0.8)],
#  's Ou': [('t', 1.0)],
#  'Out\n': [(' ', 0.5), ('\n', 0.5)],
#  'ut\n ': [(' ', 1.0)],
#  'he H': [('o', 0.08695652173913043),
#   ('i', 0.08695652173913043),
#   ('a', 0.8260869565217391)],
#  'e Ho': [('t', 0.6666666666666666), ('p', 0.3333333333333333)],
#  ' Hot': [('e', 1.0)],
#  'Hote': [('l', 1.0)],
#  'otel': [(' ', 0.6),
#   ('.', 0.2),
#   ('\n', 0.06666666666666667),
#   (',', 0.13333333333333333)],
#  'tel ': [('C', 0.2222222222222222),
#   ('a', 0.3333333333333333),
#   ('t', 0.1111111111111111),
#   ('g', 0.1111111111111111),
#   ('w', 0.1111111111111111),
#   ('i', 0.1111111111111111)],
#  'el C': [('o', 1.0)],
#  'l Co': [('n', 1.0)],
#  ' A Q': [('u', 1.0)],
#  'A Qu': [('e', 1.0)],
#  'een’': [('s', 1.0)],
#  'en’s': [(' ', 0.6829268292682927),
#   ('\n', 0.12195121951219512),
#   ('.', 0.0975609756097561),
#   (',', 0.07317073170731707),
#   (';', 0.024390243902439025)],
#  'n’s ': [('G', 0.04),
#   ('s', 0.1),
#   ('w', 0.04),
#   ('n', 0.08),
#   ('h', 0.06),
#   ('c', 0.22),
#   ('e', 0.02),
#   ('g', 0.06),
#   ('m', 0.06),
#   ('t', 0.1),
#   ('i', 0.04),
#   ('a', 0.08),
#   ('p', 0.04),
#   ('V', 0.04),
#   ('I', 0.02)],
#  '’s G': [('i', 0.6), ('r', 0.4)],
#  's Gi': [('r', 0.16666666666666666), ('l', 0.8333333333333334)],
#  ' Gir': [('l', 1.0)],
#  'Girl': [('\n', 0.5), ('s', 0.5)],
#  'irl\n': [(' ', 0.1111111111111111),
#   ('i', 0.1111111111111111),
#   ('w', 0.1111111111111111),
#   ('t', 0.1111111111111111),
#   ('f', 0.1111111111111111),
#   ('a', 0.2222222222222222),
#   ('k', 0.1111111111111111),
#   ('\n', 0.1111111111111111)],
#  'rl\n ': [(' ', 1.0)],
#  'XXXV': [(' ', 0.125), ('I', 0.75), ('.', 0.125)],
#  'he W': [('i', 0.125), ('h', 0.8125), ('o', 0.0625)],
#  'e Wi': [('n', 0.5), ('l', 0.5)],
#  ' Win': [('t', 0.6666666666666666), ('n', 0.3333333333333333)],
#  'Wint': [('e', 1.0)],
#  'inte': [('r', 0.6136363636363636),
#   ('d', 0.21022727272727273),
#   ('l', 0.011363636363636364),
#   ('n', 0.16477272727272727)],
#  'ter ': [('a', 0.17676767676767677),
#   ('o', 0.06818181818181818),
#   ('M', 0.007575757575757576),
#   ('h', 0.05303030303030303),
#   ('t', 0.20707070707070707),
#   ('i', 0.03787878787878788),
#   ('c', 0.017676767676767676),
#   ('w', 0.08585858585858586),
#   ('f', 0.03282828282828283),
#   ('l', 0.025252525252525252),
#   ('q', 0.0025252525252525255),
#   ('d', 0.030303030303030304),
#   ('b', 0.030303030303030304),
#   ('m', 0.03787878787878788),
#   ('g', 0.022727272727272728),
#   ('n', 0.020202020202020204),
#   ('y', 0.012626262626262626),
#   ('p', 0.015151515151515152),
#   ('S', 0.010101010101010102),
#   ('j', 0.005050505050505051),
#   ('N', 0.0025252525252525255),
#   ('B', 0.005050505050505051),
#   ('r', 0.007575757575757576),
#   ('I', 0.015151515151515152),
#   ('s', 0.03535353535353535),
#   ('e', 0.010101010101010102),
#   ('u', 0.010101010101010102),
#   ('D', 0.0025252525252525255),
#   ('R', 0.010101010101010102),
#   ('v', 0.0025252525252525255)],
#  'er a': [('t', 0.09627329192546584),
#   ('s', 0.07763975155279502),
#   ('f', 0.031055900621118012),
#   ('d', 0.009316770186335404),
#   ('n', 0.40062111801242234),
#   ('l', 0.11180124223602485),
#   (' ', 0.10248447204968944),
#   ('r', 0.040372670807453416),
#   ('g', 0.034161490683229816),
#   ('u', 0.009316770186335404),
#   ('m', 0.021739130434782608),
#   ('b', 0.034161490683229816),
#   ('i', 0.003105590062111801),
#   ('\n', 0.012422360248447204),
#   ('v', 0.003105590062111801),
#   ('p', 0.006211180124223602),
#   ('c', 0.003105590062111801),
#   ('w', 0.003105590062111801)],
#  'r at': [(' ', 0.8863636363636364),
#   ('\n', 0.06818181818181818),
#   ('t', 0.022727272727272728),
#   ('e', 0.022727272727272728)],
#  'at Q': [('u', 1.0)],
#  't Qu': [('e', 1.0)],
#  'n’s\n': [(' ', 0.16666666666666666),
#   ('e', 0.16666666666666666),
#   ('A', 0.16666666666666666),
#   ('b', 0.16666666666666666),
#   ('\n', 0.16666666666666666),
#   ('s', 0.16666666666666666)],
#  '’s\n ': [(' ', 1.0)],
#  'he G': [('l', 0.2857142857142857),
#   ('u', 0.14285714285714285),
#   ('i', 0.14285714285714285),
#   ('e', 0.14285714285714285),
#   ('o', 0.14285714285714285),
#   ('r', 0.14285714285714285)],
#  'e Gl': [('o', 1.0)],
#  ' Glo': [('r', 0.5), ('v', 0.5)],
#  'Glor': [('y', 1.0)],
#  'lory': [(' ', 0.75), ('!', 0.125), ('.', 0.125)],
#  'ry a': [('n', 0.48484848484848486),
#   ('s', 0.13636363636363635),
#   ('w', 0.015151515151515152),
#   ('r', 0.030303030303030304),
#   ('c', 0.030303030303030304),
#   ('p', 0.06060606060606061),
#   ('b', 0.045454545454545456),
#   ('\n', 0.015151515151515152),
#   ('m', 0.015151515151515152),
#   ('f', 0.045454545454545456),
#   (' ', 0.06060606060606061),
#   ('i', 0.015151515151515152),
#   ('l', 0.015151515151515152),
#   ('g', 0.015151515151515152),
#   ('t', 0.015151515151515152)],
#  'nd t': [('h', 0.7744916820702403),
#   ('a', 0.04066543438077634),
#   ('o', 0.10351201478743069),
#   ('e', 0.03512014787430684),
#   ('r', 0.027726432532347505),
#   ('u', 0.0036968576709796672),
#   ('i', 0.009242144177449169),
#   ('w', 0.005545286506469501)],
#  'd th': [('e', 0.6757719714964371),
#   ('a', 0.22446555819477435),
#   ('o', 0.014251781472684086),
#   ('i', 0.05344418052256532),
#   ('r', 0.032066508313539195)],
#  'e Dr': [('e', 0.25), ('y', 0.75)],
#  ' Dre': [('a', 1.0)],
#  'Drea': [('m', 1.0)],
#  'ream': [('\n', 0.04),
#   (',', 0.03),
#   (' ', 0.21),
#   ('i', 0.17),
#   ('s', 0.21),
#   ('y', 0.01),
#   ('.', 0.11),
#   ('e', 0.15),
#   ('!', 0.03),
#   ('-', 0.01),
#   ('l', 0.02),
#   ('?', 0.01)],
#  'eam\n': [(' ', 0.2), ('a', 0.2), ('i', 0.2), ('w', 0.2), ('\n', 0.2)],
#  'am\n ': [(' ', 1.0)],
#  'm\n  ': [(' ', 1.0)],
#  ' Rea': [('p', 0.2857142857142857),
#   ('d', 0.5714285714285714),
#   ('l', 0.14285714285714285)],
#  'Reap': [('e', 1.0)],
#  'eape': [('r', 0.6666666666666666), ('d', 0.3333333333333333)],
#  'aper': [(' ', 0.6),
#   ('?', 0.04),
#   (',', 0.08),
#   ('.', 0.12),
#   ('s', 0.08),
#   ('e', 0.04),
#   ('\n', 0.04)],
#  'per ': [('W', 0.03773584905660377),
#   ('h', 0.03773584905660377),
#   ('a', 0.22641509433962265),
#   ('m', 0.018867924528301886),
#   ('b', 0.05660377358490566),
#   ('l', 0.03773584905660377),
#   ('w', 0.11320754716981132),
#   ('t', 0.09433962264150944),
#   ('n', 0.018867924528301886),
#   ('s', 0.03773584905660377),
#   ('i', 0.11320754716981132),
#   ('q', 0.018867924528301886),
#   ('r', 0.03773584905660377),
#   ('A', 0.03773584905660377),
#   ('v', 0.018867924528301886),
#   ('p', 0.018867924528301886),
#   ('c', 0.018867924528301886),
#   ('o', 0.018867924528301886),
#   ('f', 0.018867924528301886),
#   ('M', 0.018867924528301886)],
#  'er W': [('h', 0.5), ('e', 0.25), ('a', 0.25)],
#  'r Wh': [('o', 1.0)],
#  ' Who': [('s', 0.4), (' ', 0.4), ('\n', 0.2)],
#  'Whos': [('e', 1.0)],
#  'hose': [(' ', 0.8795180722891566),
#   ('\n', 0.0963855421686747),
#   (',', 0.012048192771084338),
#   ('n', 0.012048192771084338)],
#  'ose ': [('N', 0.009259259259259259),
#   ('w', 0.05555555555555555),
#   ('c', 0.013888888888888888),
#   ('o', 0.05555555555555555),
#   ('b', 0.05555555555555555),
#   ('i', 0.07407407407407407),
#   ('s', 0.08333333333333333),
#   ('t', 0.1527777777777778),
#   ('y', 0.10185185185185185),
#   ('a', 0.046296296296296294),
#   ('r', 0.023148148148148147),
#   ('I', 0.09259259259259259),
#   ('n', 0.023148148148148147),
#   ('f', 0.032407407407407406),
#   ('h', 0.032407407407407406),
#   ('_', 0.004629629629629629),
#   ('m', 0.023148148148148147),
#   ('g', 0.009259259259259259),
#   ('u', 0.004629629629629629),
#   ('d', 0.018518518518518517),
#   ('G', 0.004629629629629629),
#   ('p', 0.023148148148148147),
#   ('P', 0.004629629629629629),
#   ('M', 0.009259259259259259),
#   ('e', 0.023148148148148147),
#   ('l', 0.013888888888888888),
#   ('k', 0.004629629629629629),
#   ('F', 0.004629629629629629)],
#  'se N': [('a', 1.0)],
#  'e Na': [('m', 1.0)],
#  ' Nam': [('e', 1.0)],
#  'Name': [(' ', 1.0)],
#  'ame ': [('I', 0.017391304347826087),
#   ('a', 0.09130434782608696),
#   ('m', 0.034782608695652174),
#   ('h', 0.0782608695652174),
#   ('o', 0.10869565217391304),
#   ('t', 0.2),
#   ('l', 0.021739130434782608),
#   ('w', 0.06956521739130435),
#   ('f', 0.05652173913043478),
#   ('k', 0.008695652173913044),
#   ('i', 0.08695652173913043),
#   ('b', 0.06086956521739131),
#   ('p', 0.008695652173913044),
#   ('u', 0.043478260869565216),
#   ('y', 0.004347826086956522),
#   ('r', 0.013043478260869565),
#   ('d', 0.0391304347826087),
#   ('n', 0.008695652173913044),
#   ('V', 0.004347826086956522),
#   ('M', 0.004347826086956522),
#   ('S', 0.008695652173913044),
#   ('c', 0.008695652173913044),
#   ('v', 0.004347826086956522),
#   ('s', 0.017391304347826087)],
#  'me I': [('s', 0.09523809523809523),
#   (' ', 0.6666666666666666),
#   ('’', 0.23809523809523808)],
#  'Is D': [('e', 1.0)],
#  ...}

# %%
i = 1
for hist, chars in lm.items():
    if i==12:
        print(hist, chars)
        print(chars.values())
        print(normalize(chars))
        break
    i +=1
# Out:
# Anne Counter({' ': 2007, ',': 645, '.': 411, '’': 315, '\n': 114, '?': 66, '-': 36, '!': 12, ';': 6, '”': 6, 's': 3, ']': 3})
# dict_values([2007, 315, 645, 114, 411, 66, 36, 12, 6, 3, 6, 3])
# [(' ', 0.5538079470198676), ('’', 0.0869205298013245), (',', 0.17798013245033112), ('\n', 0.03145695364238411), ('.', 0.11341059602649006), ('?', 0.018211920529801324), ('-', 0.009933774834437087), ('!', 0.0033112582781456954), (';', 0.0016556291390728477), ('s', 0.0008278145695364238), ('”', 0.0016556291390728477), (']', 0.0008278145695364238)]

# %%
lm = train_char_lm("../data/Anne_of_Green_Gables.txt", order=4)

# %%
lm['Rach']
# Out:
# [('e', 1.0)]

# %%
lm['Gree']
# Out:
# [('n', 0.9787234042553191), ('k', 0.02127659574468085)]

# %%
lm['Mari']
# Out:
# [('l', 0.9988193624557261), ('t', 0.0011806375442739079)]

# %%
dist = lm['Anne']
dist
# Out:
# [(' ', 0.5538079470198676),
#  ('’', 0.0869205298013245),
#  (',', 0.17798013245033112),
#  ('\n', 0.03145695364238411),
#  ('.', 0.11341059602649006),
#  ('?', 0.018211920529801324),
#  ('-', 0.009933774834437087),
#  ('!', 0.0033112582781456954),
#  (';', 0.0016556291390728477),
#  ('s', 0.0008278145695364238),
#  ('”', 0.0016556291390728477),
#  (']', 0.0008278145695364238)]

# %%
# for c,v in dist:
#     print(c,v)

# %%
order = 10
lm = train_char_lm("../data/Anne_of_Green_Gables.txt", order=order)
print(generate_text(lm, order))
# Out:
# Title: Anne of Green Gables;
#    and please let me stay at Green Gables. It will restore my
# self-respect, for I wanted to know how delighted? Oh, Anne, I’ll
# tell you what you
# call me if I’m only going to give them extra lessons and plans, sometimes, but
# there’s no use in loving things and are such
# active workers in the lumber room. I’ll go and have it over.”
#
# “Marilla, _don’t_ think of something I won’t encourage.
# I hope you appreciated
# now. I feel that I have no hard
# feelings for you, Mrs. Blewett?”
#
# “I suppose that is why Marilla had listened delight. Marilla, when just being treated as if you were so frightened--now that it had been called Jedediah; but I’m _glad_ I told her it was all
# nonsense.
#
# But all the time he broke his ankle when he would die within nine
# days. He didn’t, but he died two years old.”
#
# “Humph! You don’t think that there was no necessity for
# such childish classic, “Now I lay me down to
# see me often as I could and I’ve
# pored over the brook, of still, crimson-budded

# %%
order = 10
lm = train_char_lm("../data/divan.txt", order=order)
print(generate_text(lm, order))
# Out:
# ﻿ ديوان حافظ
# غزل   ۱
#
# الا يا ايها السکارا
#
# ای صاحب کرامت شکرانه سلامت
# روزی تفقدی کن درويش بی‌نوا را
#
# آسايش دو گيتی تفسير اين دو حرف است
# با دوستان مضايقه در عمر و مال نيست
# صد جان فدای لبش شد خيال می‌بستم
# که قطره‌ای ز زلالش به کام ما افتد
#
# به بارگاه تو چون باد را نباشد برگ سرای سلطان
# ماييم و کهنه دلقی کتش در آن توان زد
#
# درويش را نباشد برگ سرای سلطان
# ماييم و کهنه دلقی کتش در آن توان زد
#
# شد رهزن سلامت زلف تو وين عجب نيست
# گر راه زن تو باشی شمع بالينم
#
# حديث آرزومندی
#
# الا ای يوسف مصری که کردت سلطنت مغرور
# پدر را بازپرس آخر کجا شد مهر فرزندی
#
# جهان پير است و بی‌بنياد از اين فرهادکش فرياد
# که کرد افسون و نيرنگش ملول از جان شيرينم
#
# مگر ديوانه خواهم شد در اين سودا که شب تا روز
# سخن با ماه می‌گويم چو گل از غم کنم گريبان چاک
#
# رود به خواب دو چشم از خيال تو چه پروای شراب است
# خم گو سر خود گير که خمخانه خراب است
#
# گر خمر بهشت است بريزيد که بی دوست نباشم هرگز
# چه توان کرد که عمر است و شتابی دارد
# باز با دلشدگان ناز و عتابی دارد
# باز با دلشدگان ناز و عتابی دارد
#
# از عدالت نبود دور گرش پرسد حال
# پادشاهی که به همساي
